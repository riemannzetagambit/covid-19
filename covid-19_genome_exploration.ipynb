# %% [markdown]
# # Initialization

# %% [markdown]
# ## Imports

# %%
from pathlib import Path
from subprocess import call

import pandas as pd
import yaml

# %% [markdown]
# ## Useful functions

# %%
_FASTQ_DUMP_BIN = '/Users/dstone/software/sratoolkit.2.9.6-1-mac64/bin/fastq-dump' # dependent on your SRA installation
def download_sra_fasta(sra_num: str, download_path: str=None, overwrite_existing: bool=False) -> int:
    out_file = Path(download_path or './', f'{sra_num}.fasta').resolve()
    if not overwrite_existing and out_file.exists():
        print(f'{sra_num} already exists. Passing.')
        return 0
    
    call_cmd = [_FASTQ_DUMP_BIN, '--fasta', sra_num]
    if download_path is not None:
          call_cmd.extend(['--outdir', str(Path(download_path).resolve())])
    print(f'Downloading {sra_num} to fasta...')
    ret_value = call(call_cmd)
    if ret_value != 0:
        raise Exception(f'Received return value from fastq-dump: {ret_value}')
    print(f'Done!')
    return ret_value

_GENBANK_URL = 'http://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=nucleotide&id={acn}&rettype=fasta'
def download_genbank_fasta(accession_num: str, download_path: str=None, overwrite_existing: bool=False) -> int:
    out_file = Path(download_path or './', f'{accession_num}.fasta').resolve()
    if not overwrite_existing and out_file.exists():
        print(f'{accession_num} already exists. Passing.')
        return 0
    
    call_cmd = ['wget', _GENBANK_URL.format(acn=accession_num)]
    if download_path is not None:
        call_cmd.extend(['--output-document', str(Path(download_path, f'{accession_num}.fasta').resolve())])
    else:
        call_cmd.extend(['--output-document', f'{accession_num}.fasta'])
    print(f'Downloading {accession_num} to fasta...')
    ret_value = call(call_cmd)
    if ret_value != 0:
        raise Exception(f'Received return value from wget: {ret_value}')
    print(f'Done!')
    return ret_value

# %% [markdown]
# ## Download latest ncov sequence accession/SRA numbers

# %% [markdown]
# NCBI is maintaining a `.yaml` file that has Genbank accession + SRA run numbers, along with metadata, at the following url

# %%
ncov_yaml_path = '/Users/dstone/projects/covid-19/ncov-sequences.yaml'
# !wget https://www.ncbi.nlm.nih.gov/core/assets/genbank/files/ncov-sequences.yaml \
    --output-document  $ncov_yaml_path
# Out:
# --2020-04-12 15:48:48--  https://www.ncbi.nlm.nih.gov/core/assets/genbank/files/ncov-sequences.yaml
# Resolving www.ncbi.nlm.nih.gov (www.ncbi.nlm.nih.gov)... 130.14.29.110
# Connecting to www.ncbi.nlm.nih.gov (www.ncbi.nlm.nih.gov)|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 95960 (94K)
# Saving to: ‘/Users/dstone/projects/covid-19/ncov-sequences.yaml’
#
# /Users/dstone/proje 100%[===================>]  93.71K   389KB/s    in 0.2s
#
# 2020-04-12 15:48:49 (389 KB/s) - ‘/Users/dstone/projects/covid-19/ncov-sequences.yaml’ saved [95960/95960]

# %%
# now open that file
with open(ncov_yaml_path, 'r') as stream:
    ncov_data = yaml.safe_load(stream)

# %%
ncov_data['genbank-sequences'][0]
# Out:
# {'accession': 'MN908947',
#  'refseq-accession': 'NC_045512',
#  'gene-region': 'complete',
#  'collection-date': '2019-12',
#  'locality': {'country': 'China'}}

# %%
# acquire all genbank data
for genbank_dict in ncov_data['genbank-sequences']:
    acn, completeness = genbank_dict['accession'], genbank_dict['gene-region']
    if completeness == 'complete':
        # only download if we have a full genome
        download_genbank_fasta(acn, download_path='/Users/dstone/projects/covid-19/fastas/genbank/')
# Out:
# MN908947 already exists. Passing.
# MN938384 already exists. Passing.
# MN975262 already exists. Passing.
# MN985325 already exists. Passing.
# MN988713 already exists. Passing.
# MN994467 already exists. Passing.
# MN994468 already exists. Passing.
# MN997409 already exists. Passing.
# MN988668 already exists. Passing.
# MN988669 already exists. Passing.
# MN996527 already exists. Passing.
# MN996528 already exists. Passing.
# MN996529 already exists. Passing.
# MN996530 already exists. Passing.
# MN996531 already exists. Passing.
# MT007544 already exists. Passing.
# LR757995 already exists. Passing.
# LR757996 already exists. Passing.
# LR757998 already exists. Passing.
# MT019529 already exists. Passing.
# MT019530 already exists. Passing.
# MT019531 already exists. Passing.
# MT019532 already exists. Passing.
# MT019533 already exists. Passing.
# MT020880 already exists. Passing.
# MT020881 already exists. Passing.
# MT027062 already exists. Passing.
# MT027063 already exists. Passing.
# MT027064 already exists. Passing.
# MT039873 already exists. Passing.
# MT039887 already exists. Passing.
# MT039888 already exists. Passing.
# MT039890 already exists. Passing.
# MT044257 already exists. Passing.
# MT044258 already exists. Passing.
# MT049951 already exists. Passing.
# MT066175 already exists. Passing.
# MT066176 already exists. Passing.
# MT072688 already exists. Passing.
# MT093571 already exists. Passing.
# MT093631 already exists. Passing.
# MT106052 already exists. Passing.
# MT106053 already exists. Passing.
# MT106054 already exists. Passing.
# MT118835 already exists. Passing.
# MT123290 already exists. Passing.
# MT123291 already exists. Passing.
# MT123292 already exists. Passing.
# MT123293 already exists. Passing.
# LC528232 already exists. Passing.
# LC528233 already exists. Passing.
# MT126808 already exists. Passing.
# MT135041 already exists. Passing.
# MT135042 already exists. Passing.
# MT135043 already exists. Passing.
# MT135044 already exists. Passing.
# MT152824 already exists. Passing.
# MT012098 already exists. Passing.
# MT050493 already exists. Passing.
# MT121215 already exists. Passing.
# MT159705 already exists. Passing.
# MT159706 already exists. Passing.
# MT159707 already exists. Passing.
# MT159708 already exists. Passing.
# MT159709 already exists. Passing.
# MT159710 already exists. Passing.
# MT159711 already exists. Passing.
# MT159712 already exists. Passing.
# MT159713 already exists. Passing.
# MT159714 already exists. Passing.
# MT159715 already exists. Passing.
# MT159716 already exists. Passing.
# MT159717 already exists. Passing.
# MT159718 already exists. Passing.
# MT159719 already exists. Passing.
# MT159720 already exists. Passing.
# MT159721 already exists. Passing.
# MT159722 already exists. Passing.
# MT066156 already exists. Passing.
# MT163716 already exists. Passing.
# MT163717 already exists. Passing.
# MT163718 already exists. Passing.
# MT163719 already exists. Passing.
# LC529905 already exists. Passing.
# MT184907 already exists. Passing.
# MT184908 already exists. Passing.
# MT184909 already exists. Passing.
# MT184910 already exists. Passing.
# MT184911 already exists. Passing.
# MT184912 already exists. Passing.
# MT184913 already exists. Passing.
# MT188339 already exists. Passing.
# MT188340 already exists. Passing.
# MT188341 already exists. Passing.
# MT192759 already exists. Passing.
# MT192765 already exists. Passing.
# MT192772 already exists. Passing.
# MT192773 already exists. Passing.
# MT198652 already exists. Passing.
# MT226610 already exists. Passing.
# MT233519 already exists. Passing.
# MT233522 already exists. Passing.
# MT233523 already exists. Passing.
# MT240479 already exists. Passing.
# MT246449 already exists. Passing.
# MT246450 already exists. Passing.
# MT246451 already exists. Passing.
# MT246452 already exists. Passing.
# MT246453 already exists. Passing.
# MT246454 already exists. Passing.
# MT246455 already exists. Passing.
# MT246456 already exists. Passing.
# MT246457 already exists. Passing.
# MT246458 already exists. Passing.
# MT246459 already exists. Passing.
# MT246460 already exists. Passing.
# MT246461 already exists. Passing.
# MT246462 already exists. Passing.
# MT246464 already exists. Passing.
# MT246466 already exists. Passing.
# MT246467 already exists. Passing.
# MT246468 already exists. Passing.
# MT246469 already exists. Passing.
# MT246470 already exists. Passing.
# MT246471 already exists. Passing.
# MT246472 already exists. Passing.
# MT246473 already exists. Passing.
# MT246474 already exists. Passing.
# MT246475 already exists. Passing.
# MT246476 already exists. Passing.
# MT246477 already exists. Passing.
# MT246478 already exists. Passing.
# MT246479 already exists. Passing.
# MT246480 already exists. Passing.
# MT246481 already exists. Passing.
# MT246482 already exists. Passing.
# MT246484 already exists. Passing.
# MT246485 already exists. Passing.
# MT246486 already exists. Passing.
# MT246487 already exists. Passing.
# MT246488 already exists. Passing.
# MT246489 already exists. Passing.
# MT246490 already exists. Passing.
# MT251972 already exists. Passing.
# MT251973 already exists. Passing.
# MT251974 already exists. Passing.
# MT251975 already exists. Passing.
# MT251976 already exists. Passing.
# MT251977 already exists. Passing.
# MT251978 already exists. Passing.
# MT251979 already exists. Passing.
# MT251980 already exists. Passing.
# MT253696 already exists. Passing.
# MT253697 already exists. Passing.
# MT253698 already exists. Passing.
# MT253699 already exists. Passing.
# MT253700 already exists. Passing.
# MT253701 already exists. Passing.
# MT253702 already exists. Passing.
# MT253703 already exists. Passing.
# MT253704 already exists. Passing.
# MT253705 already exists. Passing.
# MT253706 already exists. Passing.
# MT253707 already exists. Passing.
# MT253708 already exists. Passing.
# MT253709 already exists. Passing.
# MT253710 already exists. Passing.
# MT258377 already exists. Passing.
# MT258378 already exists. Passing.
# MT258379 already exists. Passing.
# MT258380 already exists. Passing.
# MT258381 already exists. Passing.
# MT258382 already exists. Passing.
# MT258383 already exists. Passing.
# MT259226 already exists. Passing.
# MT259227 already exists. Passing.
# MT259228 already exists. Passing.
# MT259229 already exists. Passing.
# MT259230 already exists. Passing.
# MT259231 already exists. Passing.
# MT259235 already exists. Passing.
# MT259236 already exists. Passing.
# MT259237 already exists. Passing.
# MT259239 already exists. Passing.
# MT259241 already exists. Passing.
# MT259243 already exists. Passing.
# MT259244 already exists. Passing.
# MT259245 already exists. Passing.
# MT259246 already exists. Passing.
# MT259247 already exists. Passing.
# MT259248 already exists. Passing.
# MT259249 already exists. Passing.
# MT259250 already exists. Passing.
# MT259251 already exists. Passing.
# MT259252 already exists. Passing.
# MT259253 already exists. Passing.
# MT259254 already exists. Passing.
# MT259256 already exists. Passing.
# MT259257 already exists. Passing.
# MT259258 already exists. Passing.
# MT259260 already exists. Passing.
# MT259261 already exists. Passing.
# MT259263 already exists. Passing.
# MT259264 already exists. Passing.
# MT259266 already exists. Passing.
# MT259267 already exists. Passing.
# MT259268 already exists. Passing.
# MT259269 already exists. Passing.
# MT259271 already exists. Passing.
# MT259273 already exists. Passing.
# MT259274 already exists. Passing.
# MT259275 already exists. Passing.
# MT259277 already exists. Passing.
# MT259278 already exists. Passing.
# MT259280 already exists. Passing.
# MT259281 already exists. Passing.
# MT259282 already exists. Passing.
# MT259284 already exists. Passing.
# MT259285 already exists. Passing.
# MT259286 already exists. Passing.
# MT259287 already exists. Passing.
# MT262896 already exists. Passing.
# MT262897 already exists. Passing.
# MT262898 already exists. Passing.
# MT262899 already exists. Passing.
# MT262900 already exists. Passing.
# MT262901 already exists. Passing.
# MT262902 already exists. Passing.
# MT262903 already exists. Passing.
# MT262904 already exists. Passing.
# MT262905 already exists. Passing.
# MT262906 already exists. Passing.
# MT262907 already exists. Passing.
# MT262908 already exists. Passing.
# MT262909 already exists. Passing.
# MT262910 already exists. Passing.
# MT262911 already exists. Passing.
# MT262912 already exists. Passing.
# MT262913 already exists. Passing.
# MT262914 already exists. Passing.
# MT262915 already exists. Passing.
# MT262916 already exists. Passing.
# MT262993 already exists. Passing.
# MT263074 already exists. Passing.
# MT263381 already exists. Passing.
# MT263382 already exists. Passing.
# MT263383 already exists. Passing.
# MT263384 already exists. Passing.
# MT263386 already exists. Passing.
# MT263387 already exists. Passing.
# MT263388 already exists. Passing.
# MT263390 already exists. Passing.
# MT263391 already exists. Passing.
# MT263392 already exists. Passing.
# MT263394 already exists. Passing.
# MT263395 already exists. Passing.
# MT263396 already exists. Passing.
# MT263398 already exists. Passing.
# MT263399 already exists. Passing.
# MT263400 already exists. Passing.
# MT263402 already exists. Passing.
# MT263403 already exists. Passing.
# MT263404 already exists. Passing.
# MT263405 already exists. Passing.
# MT263406 already exists. Passing.
# MT263408 already exists. Passing.
# MT263410 already exists. Passing.
# MT263411 already exists. Passing.
# MT263412 already exists. Passing.
# MT263413 already exists. Passing.
# MT263414 already exists. Passing.
# MT263415 already exists. Passing.
# MT263416 already exists. Passing.
# MT263417 already exists. Passing.
# MT263418 already exists. Passing.
# MT263419 already exists. Passing.
# MT263420 already exists. Passing.
# MT263421 already exists. Passing.
# MT263422 already exists. Passing.
# MT263423 already exists. Passing.
# MT263424 already exists. Passing.
# MT263425 already exists. Passing.
# MT263426 already exists. Passing.
# MT263428 already exists. Passing.
# MT263429 already exists. Passing.
# MT263430 already exists. Passing.
# MT263431 already exists. Passing.
# MT263432 already exists. Passing.
# MT263433 already exists. Passing.
# MT263434 already exists. Passing.
# MT263435 already exists. Passing.
# MT263436 already exists. Passing.
# MT263437 already exists. Passing.
# MT263438 already exists. Passing.
# MT263439 already exists. Passing.
# MT263440 already exists. Passing.
# MT263441 already exists. Passing.
# MT263442 already exists. Passing.
# MT263443 already exists. Passing.
# MT263444 already exists. Passing.
# MT263445 already exists. Passing.
# MT263446 already exists. Passing.
# MT263447 already exists. Passing.
# MT263448 already exists. Passing.
# MT263449 already exists. Passing.
# MT263450 already exists. Passing.
# MT263451 already exists. Passing.
# MT263452 already exists. Passing.
# MT263453 already exists. Passing.
# MT263454 already exists. Passing.
# MT263455 already exists. Passing.
# MT263456 already exists. Passing.
# MT263457 already exists. Passing.
# MT263458 already exists. Passing.
# MT263459 already exists. Passing.
# MT263462 already exists. Passing.
# MT263463 already exists. Passing.
# MT263464 already exists. Passing.
# MT263465 already exists. Passing.
# MT263467 already exists. Passing.
# MT263468 already exists. Passing.
# MT263469 already exists. Passing.
# LC534418 already exists. Passing.
# LC534419 already exists. Passing.
# Downloading MT233526 to fasta...
# Done!
# Downloading MT246667 to fasta...
# Done!
# Downloading MT276323 to fasta...
# Done!
# Downloading MT276324 to fasta...
# Done!
# Downloading MT276325 to fasta...
# Done!
# Downloading MT276326 to fasta...
# Done!
# Downloading MT276327 to fasta...
# Done!
# Downloading MT276328 to fasta...
# Done!
# Downloading MT276329 to fasta...
# Done!
# Downloading MT276330 to fasta...
# Done!
# Downloading MT276331 to fasta...
# Done!
# Downloading MT276597 to fasta...
# Done!
# Downloading MT276598 to fasta...
# Done!
# Downloading MT281577 to fasta...
# Done!
# Downloading MT291826 to fasta...
# Done!
# Downloading MT291827 to fasta...
# Done!
# Downloading MT291828 to fasta...
# Done!
# Downloading MT291829 to fasta...
# Done!
# Downloading MT291830 to fasta...
# Done!
# Downloading MT291831 to fasta...
# Done!
# Downloading MT291832 to fasta...
# Done!
# Downloading MT291833 to fasta...
# Done!
# Downloading MT291834 to fasta...
# Done!
# Downloading MT291835 to fasta...
# Done!
# Downloading MT291836 to fasta...
# Done!
# Downloading MT292569 to fasta...
# Done!
# Downloading MT292570 to fasta...
# Done!
# Downloading MT292571 to fasta...
# Done!
# Downloading MT292572 to fasta...
# Done!
# Downloading MT292573 to fasta...
# Done!
# Downloading MT292574 to fasta...
# Done!
# Downloading MT292575 to fasta...
# Done!
# Downloading MT293156 to fasta...
# Done!
# Downloading MT293158 to fasta...
# Done!
# Downloading MT293159 to fasta...
# Done!
# Downloading MT293160 to fasta...
# Done!
# Downloading MT293161 to fasta...
# Done!
# Downloading MT293162 to fasta...
# Done!
# Downloading MT293163 to fasta...
# Done!
# Downloading MT293164 to fasta...
# Done!
# Downloading MT293165 to fasta...
# Done!
# Downloading MT293166 to fasta...
# Done!
# Downloading MT293167 to fasta...
# Done!
# Downloading MT293168 to fasta...
# Done!
# Downloading MT293169 to fasta...
# Done!
# Downloading MT293170 to fasta...
# Done!
# Downloading MT293171 to fasta...
# Done!
# Downloading MT293172 to fasta...
# Done!
# Downloading MT293173 to fasta...
# Done!
# Downloading MT293174 to fasta...
# Done!
# Downloading MT293175 to fasta...
# Done!
# Downloading MT293176 to fasta...
# Done!
# Downloading MT293177 to fasta...
# Done!
# Downloading MT293178 to fasta...
# Done!
# Downloading MT293179 to fasta...
# Done!
# Downloading MT293180 to fasta...
# Done!
# Downloading MT293181 to fasta...
# Done!
# Downloading MT293182 to fasta...
# Done!
# Downloading MT293183 to fasta...
# Done!
# Downloading MT293184 to fasta...
# Done!
# Downloading MT293185 to fasta...
# Done!
# Downloading MT293186 to fasta...
# Done!
# Downloading MT293187 to fasta...
# Done!
# Downloading MT293188 to fasta...
# Done!
# Downloading MT293189 to fasta...
# Done!
# Downloading MT293190 to fasta...
# Done!
# Downloading MT293191 to fasta...
# Done!
# Downloading MT293192 to fasta...
# Done!
# Downloading MT293194 to fasta...
# Done!
# Downloading MT293195 to fasta...
# Done!
# Downloading MT293196 to fasta...
# Done!
# Downloading MT293197 to fasta...
# Done!
# Downloading MT293198 to fasta...
# Done!
# Downloading MT293199 to fasta...
# Done!
# Downloading MT293200 to fasta...
# Done!
# Downloading MT293201 to fasta...
# Done!
# Downloading MT293202 to fasta...
# Done!
# Downloading MT293204 to fasta...
# Done!
# Downloading MT293205 to fasta...
# Done!
# Downloading MT293206 to fasta...
# Done!
# Downloading MT293207 to fasta...
# Done!
# Downloading MT293208 to fasta...
# Done!
# Downloading MT293209 to fasta...
# Done!
# Downloading MT293210 to fasta...
# Done!
# Downloading MT293211 to fasta...
# Done!
# Downloading MT293212 to fasta...
# Done!
# Downloading MT293213 to fasta...
# Done!
# Downloading MT293215 to fasta...
# Done!
# Downloading MT293216 to fasta...
# Done!
# Downloading MT293218 to fasta...
# Done!
# Downloading MT293219 to fasta...
# Done!
# Downloading MT293220 to fasta...
# Done!
# Downloading MT293222 to fasta...
# Done!
# Downloading MT293224 to fasta...
# Done!
# Downloading MT293225 to fasta...
# Done!
# Downloading MT295464 to fasta...
# Done!
# Downloading MT295465 to fasta...
# Done!
# Downloading MT300186 to fasta...
# Done!
# Downloading MT304474 to fasta...
# Done!
# Downloading MT304475 to fasta...
# Done!
# Downloading MT304476 to fasta...
# Done!
# Downloading MT304477 to fasta...
# Done!
# Downloading MT304478 to fasta...
# Done!
# Downloading MT304479 to fasta...
# Done!
# Downloading MT304480 to fasta...
# Done!
# Downloading MT304481 to fasta...
# Done!
# Downloading MT304482 to fasta...
# Done!
# Downloading MT304483 to fasta...
# Done!
# Downloading MT304484 to fasta...
# Done!
# Downloading MT304485 to fasta...
# Done!
# Downloading MT304486 to fasta...
# Done!
# Downloading MT304487 to fasta...
# Done!
# Downloading MT304488 to fasta...
# Done!
# Downloading MT304489 to fasta...
# Done!
# Downloading MT304490 to fasta...
# Done!
# Downloading MT304491 to fasta...
# Done!
# Downloading MT308693, gapped to fasta...
# Done!
# Downloading MT308694, gapped to fasta...
# Done!
# Downloading MT308695, gapped to fasta...
# Done!
# Downloading MT308696, gapped to fasta...
# Done!
# Downloading MT308697, gapped to fasta...
# Done!
# Downloading MT308698, gapped to fasta...
# Done!
# Downloading MT308699, gapped to fasta...
# Done!
# Downloading MT308700, gapped to fasta...
# Done!
# Downloading MT308702 to fasta...
# Done!
# Downloading MT308703 to fasta...
# Done!
# Downloading MT308704 to fasta...
# Done!
# Downloading MT320538 to fasta...
# Done!
# Downloading MT320891 to fasta...
# Done!
# Downloading MT039874 to fasta...
# Done!
# Downloading MT077125 to fasta...
# Done!
# Downloading MT322394 to fasta...
# Done!
# Downloading MT322395 to fasta...
# Done!
# Downloading MT322396 to fasta...
# Done!
# Downloading MT322397 to fasta...
# Done!
# Downloading MT322398 to fasta...
# Done!
# Downloading MT322400 to fasta...
# Done!
# Downloading MT322401 to fasta...
# Done!
# Downloading MT322402 to fasta...
# Done!
# Downloading MT322403 to fasta...
# Done!
# Downloading MT322404 to fasta...
# Done!
# Downloading MT322405 to fasta...
# Done!
# Downloading MT322406 to fasta...
# Done!
# Downloading MT322407 to fasta...
# Done!
# Downloading MT322408 to fasta...
# Done!
# Downloading MT322409 to fasta...
# Done!
# Downloading MT322410 to fasta...
# Done!
# Downloading MT322411 to fasta...
# Done!
# Downloading MT322412 to fasta...
# Done!
# Downloading MT322413 to fasta...
# Done!
# Downloading MT322414 to fasta...
# Done!
# Downloading MT322415 to fasta...
# Done!
# Downloading MT322416 to fasta...
# Done!
# Downloading MT322417 to fasta...
# Done!
# Downloading MT322418 to fasta...
# Done!
# Downloading MT322419 to fasta...
# Done!
# Downloading MT322420 to fasta...
# Done!
# Downloading MT322421 to fasta...
# Done!
# Downloading MT322422 to fasta...
# Done!
# Downloading MT322423 to fasta...
# Done!
# Downloading MT322424 to fasta...
# Done!

# %%
# this stalls after the first few downloads every time, so will stick with the genbank sequences for now
# # acquire all SRA data
# for genbank_dict in ncov_data['sra-accessions']:
#     sra_num = genbank_dict['sra-run']
#     download_sra_fasta(sra_num, download_path='/Users/dstone/projects/covid-19/fastas/sra/', overwrite_existing=False)

# %% [markdown]
# ## Create dataframe of all accession information

# %%
ncov_data['genbank-sequences'][0]
# Out:
# {'refseq-accession': 'NC_045512',
#  'gene-region': 'complete',
#  'collection-date': '2019-12',
#  'locality': {'country': 'China'}}

# %%
metadata_fields = ['collection-date', 'country', 'state']
df_metadata = pd.DataFrame(columns=metadata_fields)
for sd in ncov_data['genbank-sequences']:
    row_dict = {}
    for mf in metadata_fields:
        if mf in ['country', 'state']:
            row_dict[mf] = sd['locality'].get(mf)
        else:
            row_dict[mf] = sd[mf]
    df_metadata.loc[sd['accession']] = row_dict

# %% [markdown]
# # Running analysis on sequences

# %% [markdown]
# ### Run MUSCLE locally
#
# Get MUSCLE:
# ```bash
#  wget http://www.drive5.com/muscle/downloads3.8.31/muscle3.8.31_i86darwin64.tar.gz --directory-prefix ~/projects/covid-19/
#  cd ~/projects/covid-19/
#  tar -xvzf muscle3.8.31_i86darwin64.tar.gz # yields a binary
#  # combine above download fastas into one fasta for alignment
#  cd ~/projects/covid-19/fastas/genbank
#  # assumes there is one read per fasta (the above download code does yield this)
#  cat *.fasta > all_ncov_genomes.fa
#  # run MUSCLE, use default parameters
#  cd ~/projects/covid-19/
#  ./muscle3.8.31_i86darwin64 -in fastas/genbank/all_ncov_genomes.fa -out ./ncov_muscle_alignments.fa
#  # time taken: ~
# ```

# %% [markdown]
# Took too long (at least 24 hours). Current output:
# ```
# dstone@5prime:~/projects/covid-19$ ./muscle3.8.31_i86darwin64 -in fastas/genbank/all_ncov_genomes.fa -out ./ncov_muscle_alignments.fa
#
# MUSCLE v3.8.31 by Robert C. Edgar
#
# http://www.drive5.com/muscle
# This software is donated to the public domain.
# Please cite: Edgar, R.C. Nucleic Acids Res 32(5), 1792-97.
#
# all_ncov_genomes 485 seqs, max length 29945, avg  length 29847
# 00:00:22     79 MB(0%)  Iter   1  100.00%  K-mer dist pass 1
# 00:00:22     79 MB(0%)  Iter   1  100.00%  K-mer dist pass 2
# 02:25:18  4706 MB(27%)  Iter   1  100.00%  Align node
# 02:25:18  4727 MB(28%)  Iter   1  100.00%  Root alignment
# 04:26:24  4727 MB(28%)  Iter   2  100.00%  Refine tree
# 04:26:24  4727 MB(28%)  Iter   2  100.00%  Root alignment
# 04:26:24  4727 MB(28%)  Iter   2  100.00%  Root alignment
# 08:48:38  4727 MB(28%)  Iter   3  100.00%  Refine biparts
# ^[[B^[[B  4727 MB(28%)  Iter   4   40.33%  Refine biparts
# ```
#
# **Solution: look up if it is memory or CPU intensive and spin up an AWS ma

# %% [markdown]
# ### Build phylogenetic tree from MUSCLE output

# %% [markdown]
# ## Alternate Method of building tree: k-mer based

# %% [markdown]
# ### Run jobs to compute k-mer profiles for each strain downloaded

# %% [markdown]
# ### For varying values of `k`, use D_2 metric to compute distances

# %% [markdown]
# ### Build phylogenetic tree from this distance method

# %% [markdown]
# ### Compare with results from MUSCLE-alignment tree
